# %%
# https://openstax.org/books/calculus-volume-1/pages/4-3-maxima-and-minima
#
# Exercise 4.13 (a) - Locating Absolute Extrema

# %%
import matplotlib as plt
from sympy import diff, Eq, solve, plot
from sympy.abc import x
init_printing()

# %%
# our function
d0 = -x**2 + 3*x - 2

# Y @ endpoints of [1, 3]
d0.subs({'x': 1}), d0.subs({'x': 3})
# Out:
# (0, -2)

# %%
# first derivative
d1 = diff(d0)
d1
# Out:
# 3 - 2⋅x

# %%
# solve first derivative to find critical points
solve(Eq(d1, 0))
# Out:
# [3/2]

# %%
plot(d0, xlim=(0, 3.5), ylim=(-5, 1))

# %%
# value of Y @ critical point of 3/2
d0.subs({'x': 3/2})
# Out:
# 0.250000000000000

# %%
print('''
    x    |    f(x)    |  description
==================================================
    1    |    0       |
    3/2  |    1/4     | absolute maxima
    3    |    -2      | absolute minima (endpoint)
''')
# Out:
#     x    |    f(x)    |  description
# ...
#     1    |    0       |
#     3/2  |    1/4     | absolute maxima
#     3    |    -2      | absolute minima (endpoint)
